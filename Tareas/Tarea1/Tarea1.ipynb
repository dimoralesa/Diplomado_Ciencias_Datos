# %% [markdown]
# <a href="https://colab.research.google.com/github/dimoralesa/Diplomado_Ciencias_Datos/blob/main/Tareas/Tarea1/Tarea1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #RANGO INTERCUARTÍLICO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-06-07 at 10.01.54 AM.jpeg](data:image/jpeg;base64,...)
#
# #### Autor: Diego Phelipe Morales Aldana
# ##### Soy estudiante de Estadística y ciencias de la computación, este semestre es el quinto que estoy inscrito en la Universidad Nacional de Colombia.

# %% [markdown]
# El rango intercuartílico es una medida de variabilidad adecuada cuando la medida de posición central empleada ha sido la mediana. Se define como la diferencia entre el tercer cuartil (Q3) y el primer cuartil (Q1), es decir: RQ = Q3 - Q1. A la mitad del rango intercuartil se le conoce como desviación cuartil (DQ), es afectada muy poco por cuentas extremas. Esto lo hace una buena medida de dispersión para distribuciones sesgadas: DQ = RQ/2= (Q3 - Q1)/2.
#
# Se usa para construir los diagramas de caja y bigote (box plots) que sirven para visualizar la variabilidad de una variable y comparar distribuciones de la misma variable; además de ubicar valores extremos.

# %%
import matplotlib.pyplot as plt


x = [8,3,4,1,4,3,13,1,4,1,3,3,2,4,2,13,6,7,3,5,9,8,7,10,12,20,31]

plt.boxplot(x)
plt.show

# %% [markdown]
# ### Referencia:
# - [Wikipedia][1]
#
# [1]:https://es.wikipedia.org/wiki/Rango_intercuart%C3%ADlico
